# %% [markdown]
# <a href="https://colab.research.google.com/github/spandana9318/Scikit_learn/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_california_housing
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
X, y = fetch_california_housing(return_X_y=True)

# %%
X.shape
# Out:
# (20640, 8)

# %%
y.shape
# Out:
# (20640,)

# %%
plt.scatter(X[:,0],y)

# %%
plt.scatter(X[:,1],y)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
l_reg = linear_model.LinearRegression()
model = l_reg.fit(x_train, y_train)

# %%
pred = model.predict(x_test)

# %%
pred
# Out:
# array([3.00081561, 5.14305391, 2.65909945, ..., 2.84153998, 2.09429092,
#        3.86216294])

# %%
plt.scatter(pred, y_test)

# %%
print("Accuracy", l_reg.score(X,y))
# Out:
# Accuracy 0.6060714092765466

# %%
print("Regression coeff", l_reg.coef_)
# Out:
# Regression coeff [ 4.33083354e-01  9.59645101e-03 -9.78253492e-02  5.85955754e-01
#   1.02250151e-07 -3.45065310e-03 -4.22030267e-01 -4.37582995e-01]

# %%
print("y-intercept", l_reg.intercept_)
# Out:
# y-intercept -37.27137094017548
