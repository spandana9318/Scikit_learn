# %% [markdown]
# <a href="https://colab.research.google.com/github/spandana9318/Scikit_learn/blob/main/Support_Vector_Machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target
names = iris.target_names

# %%
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
df = pd.DataFrame(X, columns = iris.feature_names)
df['species'] = iris.target
df['species'] = df['species'].replace(to_replace=[0,1,2], value=['setpsa', 'vercicolor', 'virginica' ])

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)    species
# 0                  5.1               3.5  ...               0.2     setpsa
# 1                  4.9               3.0  ...               0.2     setpsa
# 2                  4.7               3.2  ...               0.2     setpsa
# 3                  4.6               3.1  ...               0.2     setpsa
# 4                  5.0               3.6  ...               0.2     setpsa
# ..                 ...               ...  ...               ...        ...
# 145                6.7               3.0  ...               2.3  virginica
# 146                6.3               2.5  ...               1.9  virginica
# 147                6.5               3.0  ...               2.0  virginica
# 148                6.2               3.4  ...               2.3  virginica
# 149                5.9               3.0  ...               1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
sns.pairplot(data =df, hue = 'species', palette = 'Set2')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 1)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (120, 4) (120,)
# (30, 4) (30,)

# %%
from sklearn.svm import SVC
svm = SVC(kernel= 'linear', random_state=0)
svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
pred = svm.predict(X_test)

# %%
pred
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        1, 0, 2, 1, 0, 0, 1, 2])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
accuracy_score(y_test, pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]])

# %%
rbf_svc = SVC(kernel='rbf', random_state=0)
rbf_svc.fit(X_train, y_train)
rbf_pred = rbf_svc.predict(X_test)

# %%
rbf_pred
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        2, 0, 2, 1, 0, 0, 1, 2])

# %%
accuracy_score(y_test, rbf_pred)
# Out:
# 0.9666666666666667
